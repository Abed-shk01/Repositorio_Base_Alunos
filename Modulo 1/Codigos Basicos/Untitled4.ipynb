# %%
idade = int(input("Digite sua idade"))
if idade >= 18:
  print("Maior de idade")
else:
  print("Menor de iddade")
# Out:
# Digite sua idade 15
# Menor de iddade

# %%
num = int(input("Digite um numero"))
if num %2 == 0:
  print("Número par")
else:
  print("numero impar")

# %%
num = int(input("Digite um numero"))
if num %2 == 0:
  print("Número par")
else:
  print("Número impar")
